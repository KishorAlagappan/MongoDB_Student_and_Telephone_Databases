# %% [markdown]
# <a href="https://colab.research.google.com/github/KishorAlagappan/MongoDB-Task/blob/main/Student_Database_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
from pprint import pprint

# %%
client=MongoClient('mongodb+srv://Kishor:<kishor16s@>@cluster0.ee5mqy8.mongodb.net/?retryWrites=true&w=majority')

# %%
db=client["task"]
stu_col=db['students']

# %%
ds=pd.read_json("/content/students.json",lines=True)
print(ds)
# Out:
#      _id              name                                             scores
# 0      0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1      1  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2      2       Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3      3        Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4      4  Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 195  195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197  197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198  198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199  199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# [200 rows x 3 columns]

# %%
ds1=ds.to_dict("records")
ds1
# Out:
# [{'_id': 0,
#   'name': 'aimee Zank',
#   'scores': [{'score': 1.463179736705023, 'type': 'exam'},
#    {'score': 11.78273309957772, 'type': 'quiz'},
#    {'score': 35.8740349954354, 'type': 'homework'}]},
#  {'_id': 1,
#   'name': 'Aurelia Menendez',
#   'scores': [{'score': 60.06045071030959, 'type': 'exam'},
#    {'score': 52.79790691903873, 'type': 'quiz'},
#    {'score': 71.76133439165544, 'type': 'homework'}]},
#  {'_id': 2,
#   'name': 'Corliss Zuk',
#   'scores': [{'score': 67.03077096065002, 'type': 'exam'},
#    {'score': 6.301851677835235, 'type': 'quiz'},
#    {'score': 66.28344683278382, 'type': 'homework'}]},
#  {'_id': 3,
#   'name': 'Bao Ziglar',
#   'scores': [{'score': 71.64343899778332, 'type': 'exam'},
#    {'score': 24.80221293650313, 'type': 'quiz'},
#    {'score': 42.26147058804812, 'type': 'homework'}]},
#  {'_id': 4,
#   'name': 'Zachary Langlais',
#   'scores': [{'score': 78.68385091304332, 'type': 'exam'},
#    {'score': 90.2963101368042, 'type': 'quiz'},
# ...

# %%
stu_col.insert_many(ds1)

# %%
db.list_collection_names()
# Out:
# ['students']

# %%
stu_col.find_one()
# Out:
# {'_id': 0,
#  'name': 'aimee Zank',
#  'scores': [{'score': 1.463179736705023, 'type': 'exam'},
#   {'score': 11.78273309957772, 'type': 'quiz'},
#   {'score': 35.8740349954354, 'type': 'homework'}]}

# %% [markdown]
# **1.Find the student name who scored maximum scores in all (exam, quiz and homework)?**

# %%
stage1={"$unwind":"$scores"}
stage2={"$group":{"_id":"$_id", "name":{"$addToSet":'$name'}, "total_Marks":{"$sum":"$scores.score"}}}
stage3={"$sort":{"total_Marks":-1}}
stage6={"$limit":1}
for i in stu_col.aggregate([stage1,stage2, stage3, stage6]):
    pprint(i)
# Out:
# {'_id': 13, 'name': ['Jessika Dagenais'], 'total_Marks': 275.94947751518237}

# %% [markdown]
# **2) Find students who scored below average in the exam and pass mark is 40%?**

# %%
stage1={"$unwind":"$scores"}
stage2 = {"$match":{"$and":[{"scores.type":{"$in":["exam"]} },{"scores.score":{"$gt":40}} ,{"scores.score":{"$lte":52.3}}   ]}}
for i in stu_col.aggregate([stage1,stage2]):
    pprint(i)
# Out:
# {'_id': 5,
#  'name': 'Wilburn Spiess',
#  'scores': {'score': 44.87186330181261, 'type': 'exam'}}
# {'_id': 10,
#  'name': 'Denisha Cast',
#  'scores': {'score': 45.61876862259409, 'type': 'exam'}}
# {'_id': 19,
#  'name': 'Gisela Levin',
#  'scores': {'score': 44.51211101958831, 'type': 'exam'}}
# {'_id': 20,
#  'name': 'Tressa Schwing',
#  'scores': {'score': 42.17439799514388, 'type': 'exam'}}
# {'_id': 21,
#  'name': 'Rosana Vales',
#  'scores': {'score': 46.2289476258328, 'type': 'exam'}}
# {'_id': 23,
#  'name': 'Tamika Schildgen',
#  'scores': {'score': 45.65432764125526, 'type': 'exam'}}
# {'_id': 29,
#  'name': 'Gwyneth Garling',
#  'scores': {'score': 48.36644963899371, 'type': 'exam'}}
# {'_id': 42,
#  'name': 'Kayce Kenyon',
#  'scores': {'score': 44.62441703708117, 'type': 'exam'}}
# {'_id': 45,
#  'name': 'Terica Brugger',
#  'scores': {'score': 42.1011312120801, 'type': 'exam'}}
# {'_id': 57,
#  'name': 'Chad Rahe',
# ...

# %% [markdown]
# **3)Find students who scored below pass mark and assigned them as fail, and above pass mark as pass in all the categories.**

# %%
def aggr(std):
 prcntg = std.aggregate([{'$unwind':'$scores'},
                          {'$group':{"_id":"$_id","name":{"$first":"$name"},"max_score":{'$sum':"$scores.score"}}},
                          {'$addFields':{"prctg":{'$divide':["$max_score",3]}}},
                           {'$addFields':{"status":{"$cond":{'if' :{"$gte":["$prctg",40]},'then':"Pass",'else':"Fail"}}}}])
 return prcntg

prcntg = aggr(stu_col)
for i in prcntg:
 if i['prctg']>=40 and i['prctg']<=55:
     print(i)

prcntg = aggr(stu_col)
for i in prcntg:
  print(i)
# Out:
# {'_id': 162, 'name': 'Barbera Lippman', 'max_score': 123.87383657752201, 'prctg': 41.29127885917401, 'status': 'Pass'}
# {'_id': 16, 'name': 'Dodie Staller', 'max_score': 120.13675287379564, 'prctg': 40.045584291265214, 'status': 'Pass'}
# {'_id': 117, 'name': 'Bao Ziglar', 'max_score': 154.0475585018162, 'prctg': 51.34918616727207, 'status': 'Pass'}
# {'_id': 152, 'name': 'Richelle Siemers', 'max_score': 139.60355242003698, 'prctg': 46.53451747334566, 'status': 'Pass'}
# {'_id': 197, 'name': 'Tonisha Games', 'max_score': 148.83413523189756, 'prctg': 49.61137841063252, 'status': 'Pass'}
# {'_id': 73, 'name': 'Devorah Smartt', 'max_score': 132.19316603930335, 'prctg': 44.06438867976778, 'status': 'Pass'}
# {'_id': 39, 'name': 'Mariette Batdorf', 'max_score': 156.18768410864072, 'prctg': 52.062561369546906, 'status': 'Pass'}
# {'_id': 100, 'name': 'Demarcus Audette', 'max_score': 131.27751820054362, 'prctg': 43.75917273351454, 'status': 'Pass'}
# ...

# %% [markdown]
# **4)Find the total and average of the exam, quiz and homework and store them in a separate collection.**

# %%
db.create_collection('total_average')
x2 = stu_col.aggregate([{'$unwind':'$scores'},{'$group':{'_id':{'type':"$scores.type"},"total:":{'$sum':"$scores.score"},"average:":{'$avg':"$scores.score"}}}])
t_a = db.total_average
for i in x2:
  print(i)
  t_a.insert_one(i)
# Out:
# {'_id': {'type': 'homework'}, 'total:': 13563.739241322297, 'average:': 67.81869620661149}
# {'_id': {'type': 'exam'}, 'total:': 9734.734151900351, 'average:': 48.67367075950175}
# {'_id': {'type': 'quiz'}, 'total:': 9799.344638860508, 'average:': 48.99672319430254}

# %% [markdown]
# **5)Create a new collection which consists of students who scored below average and above 40% in all the categories.**

# %%
percentage = aggr(stu_col)
db.create_collection('passed_below_average')    
p_a = db.passed_below_average
for i in percentage:
  if i['percentage']>40 and i['percentage']<=55:
      print(i)
      p_a.insert_one(i)
# Out:
# {'_id': 152, 'name': 'Richelle Siemers', 'max_score': 139.60355242003698, 'prctg': 46.53451747334566, 'status': 'Pass'}
# {'_id': 154, 'name': 'Rachell Aman', 'max_score': 164.66123279589482, 'prctg': 54.887077598631606, 'status': 'Pass'}
# {'_id': 5, 'name': 'Wilburn Spiess', 'max_score': 134.0186975547794, 'prctg': 44.67289918492647, 'status': 'Pass'}
# {'_id': 35, 'name': 'Synthia Labelle', 'max_score': 137.7409456810277, 'prctg': 45.91364856034257, 'status': 'Pass'}
# {'_id': 59, 'name': 'Vinnie Auerbach', 'max_score': 131.55784600976585, 'prctg': 43.85261533658862, 'status': 'Pass'}
# {'_id': 101, 'name': 'Tania Hulett', 'max_score': 155.30833228670144, 'prctg': 51.769444095567145, 'status': 'Pass'}
# {'_id': 114, 'name': 'aimee Zank', 'max_score': 130.9721943324432, 'prctg': 43.6573981108144, 'status': 'Pass'}
# {'_id': 156, 'name': 'Kayce Kenyon', 'max_score': 144.78774966244362, 'prctg': 48.26258322081454, 'status': 'Pass'}
# ...

# %% [markdown]
# **6)Create a new collection which consists of students who scored below the fail mark in all the categories.**

# %%
percentage = aggr(stu_col)
db.create_collection('failed') 
fail = db.failed 
for i in percentage:
  if i['status'] == 'Fail':
      print(i)
      fail.insert_one(i)
# Out:
# {'_id': 92, 'name': 'Ta Sikorski', 'max_score': 115.74213180964733, 'prctg': 38.58071060321578, 'status': 'Fail'}
# {'_id': 120, 'name': 'Jenette Flanders', 'max_score': 107.87159055374062, 'prctg': 35.95719685124687, 'status': 'Fail'}
# {'_id': 0, 'name': 'aimee Zank', 'max_score': 49.11994783171814, 'prctg': 16.373315943906046, 'status': 'Fail'}
# {'_id': 14, 'name': 'Alix Sherrill', 'max_score': 118.48870352377075, 'prctg': 39.49623450792358, 'status': 'Fail'}
# {'_id': 15, 'name': 'Tambra Mercure', 'max_score': 117.50008641174173, 'prctg': 39.16669547058058, 'status': 'Fail'}
# {'_id': 145, 'name': 'Tandra Meadows', 'max_score': 87.5629850401662, 'prctg': 29.1876616800554, 'status': 'Fail'}
# {'_id': 163, 'name': 'Dinah Sauve', 'max_score': 75.2279417690119, 'prctg': 25.075980589670635, 'status': 'Fail'}
# {'_id': 28, 'name': 'Laureen Salomone', 'max_score': 93.67011710439672, 'prctg': 31.223372368132242, 'status': 'Fail'}
# ...

# %% [markdown]
# **7)Create a new collection which consists of students who scored above pass mark in all the categories.prcntg=aggr(sanjay)**

# %%
percentage = aggr(stu_col)
db.create_collection('passed')        
p = db.passed
for i in percentage:
  if i['percentage'] >= 40:
      print(i)
      p.insert_one(i)
# Out:
# {'_id': 191, 'name': 'Efrain Claw', 'max_score': 252.83317597388418, 'prctg': 84.27772532462807, 'status': 'Pass'}
# {'_id': 83, 'name': 'Tonisha Games', 'max_score': 131.11934974450202, 'prctg': 43.706449914834, 'status': 'Pass'}
# {'_id': 98, 'name': 'Carli Ector', 'max_score': 244.82763178118856, 'prctg': 81.60921059372951, 'status': 'Pass'}
# {'_id': 133, 'name': 'Gisela Levin', 'max_score': 123.94644554660488, 'prctg': 41.315481848868295, 'status': 'Pass'}
# {'_id': 139, 'name': 'Rudolph Domingo', 'max_score': 160.0864123492324, 'prctg': 53.36213744974413, 'status': 'Pass'}
# {'_id': 36, 'name': 'Eugene Magdaleno', 'max_score': 219.003552388691, 'prctg': 73.00118412956367, 'status': 'Pass'}
# {'_id': 99, 'name': 'Jaclyn Morado', 'max_score': 174.5461576760983, 'prctg': 58.18205255869943, 'status': 'Pass'}
# {'_id': 109, 'name': 'Flora Duell', 'max_score': 156.75611063955935, 'prctg': 52.252036879853115, 'status': 'Pass'}
# ...
